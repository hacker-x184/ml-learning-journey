# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
lp_data = pd.read_csv("raw_data/laptop_price.csv")

# %%
lp_data.sample(10)
# Out:
#       Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# 213      HP         2.723562         8              1000    16.544161
# 360    Asus         1.896513         8               512    11.572230
# 285    Acer         1.723528        16               512    13.471188
# 920  Lenovo         1.644451         4              1000    11.574374
# 314      HP         3.539583        16              1000    15.183653
# 833    Dell         2.625927         4               256    16.374188
# 339    Asus         1.690327         4               512    13.702871
# 338    Acer         3.208147        32              1000    16.890244
# 387      HP         3.830070        32               512    15.276666
# 922    Acer         3.959197        16               256    16.812048
#
#        Weight         Price
# 213  4.930383  31441.577747
# 360  3.408556  17278.839784
# 285  2.921717  17573.057889
# 920  4.277933  31096.734785
# 314  2.541555  32339.213793
# ...

# %%
lp_data.shape
# Out:
# (1000, 7)

# %%
lp_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   str
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), str(1)
# memory usage: 54.8 KB

# %%
lp_data.describe()
# Out:
#        Processor_Speed     RAM_Size  Storage_Capacity  Screen_Size  \
# count      1000.000000  1000.000000       1000.000000  1000.000000
# mean          2.750611    15.500000        584.576000    14.056790
# std           0.731796    10.988665        313.438517     1.705882
# min           1.511580     4.000000        256.000000    11.012111
# 25%           2.089246     8.000000        256.000000    12.635523
# 50%           2.760885    16.000000        512.000000    14.099643
# 75%           3.362610    32.000000       1000.000000    15.528590
# max           3.998534    32.000000       1000.000000    16.985737
#
#             Weight         Price
# count  1000.000000   1000.000000
# mean      3.466919  19604.187963
# std       0.866541   9406.064880
# min       2.000560   8570.012950
# 25%       2.717211  10114.012948
# 50%       3.464630  17287.241878
# 75%       4.212583  31566.214754
# max       4.990728  33503.935037

# %%
lp_data.isnull().sum()
# Out:
# Brand               0
# Processor_Speed     0
# RAM_Size            0
# Storage_Capacity    0
# Screen_Size         0
# Weight              0
# Price               0
# dtype: int64

# %%
lp_data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Brand             1000 non-null   str
#  1   Processor_Speed   1000 non-null   float64
#  2   RAM_Size          1000 non-null   int64
#  3   Storage_Capacity  1000 non-null   int64
#  4   Screen_Size       1000 non-null   float64
#  5   Weight            1000 non-null   float64
#  6   Price             1000 non-null   float64
# dtypes: float64(4), int64(2), str(1)
# memory usage: 54.8 KB

# %%
#EDA
sns.histplot(lp_data['Price'],bins=200,kde = True)
# Out:
# <Axes: xlabel='Price', ylabel='Count'>

# %%
lp_data.corr(numeric_only=True)
# Out:
#                   Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size  \
# Processor_Speed          1.000000  0.021391         -0.067576    -0.013425
# RAM_Size                 0.021391  1.000000          0.002111    -0.036002
# Storage_Capacity        -0.067576  0.002111          1.000000    -0.027560
# Screen_Size             -0.013425 -0.036002         -0.027560     1.000000
# Weight                  -0.054603 -0.025382          0.041335     0.021995
# Price                   -0.050737  0.061237          0.997908    -0.026740
#
#                     Weight     Price
# Processor_Speed  -0.054603 -0.050737
# RAM_Size         -0.025382  0.061237
# Storage_Capacity  0.041335  0.997908
# Screen_Size       0.021995 -0.026740
# Weight            1.000000  0.038417
# Price             0.038417  1.000000

# %%
sns.heatmap(lp_data.corr(numeric_only=True),annot = True)
# Out:
# <Axes: >

# %%
lp_data.columns
# Out:
# Index(['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
#        'Screen_Size', 'Weight', 'Price'],
#       dtype='str')

# %% [markdown]
# ## Usefull VAlue before EDA

# %% [markdown]
#
# ['Brand'
# 'Processor_Speed' -->Use
# 'RAM_Size' -->Use
# 'Storage_Capacity' ---> Use
# 'Screen_Size'-->Not really
# 'Weight' -- >USe
# ]

# %%
sns.boxplot(data=lp_data,x= 'Brand',y = 'Price')
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
sns.boxplot(data=lp_data,x='Processor_Speed',y = 'Price')
# Out:
# <Axes: xlabel='Processor_Speed', ylabel='Price'>

# %%
sns.boxplot(data=lp_data,x='RAM_Size',y = 'Price')
# Out:
# <Axes: xlabel='RAM_Size', ylabel='Price'>

# %%
sns.boxplot(data=lp_data,x='Storage_Capacity',y = 'Price')
# Out:
# <Axes: xlabel='Storage_Capacity', ylabel='Price'>

# %%
sns.scatterplot(data=lp_data,x= 'Brand',y ='Price')
# Out:
# <Axes: xlabel='Brand', ylabel='Price'>

# %%
X = lp_data.drop(columns='Price')
y = lp_data['Price']

# %%
X.head()
y
# Out:
# 0      17395.093065
# 1      31607.605919
# 2       9291.023542
# 3      17436.728334
# 4      32917.990718
#            ...
# 995    31593.668017
# 996     9149.521832
# 997    16552.404779
# 998     9407.473459
# 999     8807.696702
# Name: Price, Length: 1000, dtype: float64

# %%
X.head()
# Out:
#     Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight
# 0    Asus         3.830296        16               512    11.185147  2.641094
# 1    Acer         2.912833         4              1000    11.311372  3.260012
# 2  Lenovo         3.241627         4               256    11.853023  2.029061
# 3    Acer         3.806248        16               512    12.280360  4.573865
# 4    Acer         3.268097        32              1000    14.990877  4.193472

# %%
X_encoded = pd.get_dummies(data=X,columns=['Brand','Storage_Capacity','RAM_Size'],drop_first=True,dtype=int)

# %%
X_encoded.shape
# Out:
# (1000, 12)

# %%
from sklearn.preprocessing import LabelEncoder

# %%
Xlabel = X
columns=['Brand','Storage_Capacity','RAM_Size']

# %%
Xlabel = X
columns=['Brand','Storage_Capacity','RAM_Size']
for i in columns:
    label = LabelEncoder()
    Xlabel[i] = label.fit_transform(Xlabel[i])

# %%
Xlabel.sample()
# Out:
#      Brand  Processor_Speed  RAM_Size  Storage_Capacity  Screen_Size    Weight
# 240      4         2.349687         3                 0    16.421351  3.476163

# %%
from sklearn.preprocessing import StandardScaler
numerical_cols = ['Processor_Speed','Screen_Size','Weight']
scaler = StandardScaler()
X_encoded[numerical_cols] = scaler.fit_transform(X_encoded[numerical_cols])

# %%
X_encoded
# Out:
#      Processor_Speed  Screen_Size    Weight  Brand_Asus  Brand_Dell  Brand_HP  \
# 0           1.476128    -1.684219 -0.953490           1           0         0
# 1           0.221788    -1.610189 -0.238893           0           0         0
# 2           0.671310    -1.292510 -1.660138           0           0         0
# 3           1.443251    -1.041877  1.278069           0           0         0
# 4           0.707499     0.547843  0.838871           0           0         0
# ..               ...          ...       ...         ...         ...       ...
# 995         0.810704    -0.861977 -0.351596           0           0         1
# 996         0.040939    -0.807865  0.327148           0           1         0
# 997         0.615176    -0.815514 -0.085795           0           1         0
# 998        -1.567379    -1.666370  0.451091           1           0         0
# 999        -1.420000     1.469013 -0.030062           0           0         0
#
# ...

# %%
Xlabel[['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
       'Screen_Size', 'Weight']] = scaler.fit_transform(Xlabel[['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
       'Screen_Size', 'Weight']])
# Out:
# Index(['Brand', 'Processor_Speed', 'RAM_Size', 'Storage_Capacity',
#        'Screen_Size', 'Weight'],
#       dtype='str')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error,root_mean_squared_error,r2_score

# %%
model = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(
    X_encoded, y, test_size=0.33, random_state=42)
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)
y_pred
# Out:
# array([10715.40209335, 31573.505977  ,  9632.90985381,  9250.24452954,
#        32036.1181317 , 31644.83075797, 10335.8813722 , 16979.05215505,
#        18494.29421151, 32387.55926081,  9911.75228194, 10607.66166398,
#        32906.33671383,  9275.91102108, 17250.35752118,  8953.07228465,
#        32086.25605443, 32214.0434187 , 10489.43260203, 31671.12941588,
#        10598.7399109 , 10668.58253376,  9165.96175604, 10361.13086968,
#         9477.21817072, 17522.22385188, 10714.01962218, 18279.17967739,
#        10807.7638927 , 32675.00740479, 16882.87963536, 32787.5285458 ,
#        16668.30593957, 31915.82056105, 31612.65897786, 10547.28873505,
#        31217.92370947,  9011.28703403, 32628.89167137, 17308.668208  ,
#        32191.90941093,  9560.09650334, 17599.10897702, 31719.32875106,
#        17217.40785929, 16758.45870685, 32684.64731153, 16786.5173347 ,
#         9692.94493781, 17036.37223635, 16921.17722526, 31590.48387919,
# ...

# %%
y_test
# Out:
# 521    10900.502075
# 737    31727.516697
# 740     9636.022750
# 660     9412.599857
# 411    31641.105861
#            ...
# 506    31505.462184
# 342    16972.930010
# 485     9842.035171
# 711    10668.030494
# 133    17980.795929
# Name: Price, Length: 330, dtype: float64

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.9995786506757176

# %%
n = X_test.shape[0]
p = X_test.shape[1]
adjusted_r2 = 1-((1-r2)*(n-1))/(n-p-1)
print("Adjusted r2: - ",adjusted_r2)
# Out:
# Adjusted r2: -  0.9995627005435681

# %%
model.fmodel = LinearRegression()
X_train, X_test, y_train, y_test = train_test_split(
    Xlabel, y, test_size=0.33, random_state=42)
model.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
y_pred
# Out:
# array([ 9607.51720181, 30733.90659468,  8959.08752706,  7955.25884539,
#        30998.7248782 , 30677.88223627,  9097.80238521, 19251.32622641,
#        20633.46117267, 31549.36143836,  8911.07930742,  9330.63622694,
#        31746.43087542,  8380.87723911, 19994.57268246,  7961.97933888,
#        31306.63710323, 31227.8471122 ,  9369.51265371, 30788.56329193,
#         9471.14501812,  9372.52452237,  8095.51291118,  8958.69974213,
#         8806.06416451, 20264.94410507,  9489.37757688, 20356.24962085,
#         9376.6498247 , 31293.13085703, 19325.3832666 , 31303.32129324,
#        19213.76692046, 30991.49257755, 30551.98274297,  9173.37238128,
#        30277.65439266,  8015.29289555, 31150.58946104, 19991.06203898,
#        31416.44033382,  8631.20998125, 20362.29475237, 30762.6323071 ,
#        19906.12842936, 19239.73936851, 31382.19715519, 19122.44574989,
#         8755.98078396, 19406.26075259, 19292.78362692, 30841.61561466,
# ...

# %%
r2 = r2_score(y_test,y_pred)
r2
# Out:
# 0.9692501982380486

# %%
n = X_test.shape[0]
p = X_test.shape[1]
adjusted_r2 = 1-((1-r2)*(n-1))/(n-p-1)
print("Adjusted r2: - ",adjusted_r2)
# Out:
# Adjusted r2: -  0.9686789944901486
